# %% [markdown]
# # Financial Performance Analysis of S&P 500 Companies

# %% [markdown]
# # Team V.I.T.R.I.O.L Member
#
# - Abdulsamet Balveren, balveren15@itu.edu.tr & balveren16@gmail.com, 090190751

# %% [markdown]
# ## Project Description

# %% [markdown]
# In this project, the financial performance of the companies in the S&P 500 index will be analyzed in detail using the "S&P 500 Companies with Financial Information" dataset on the Datahub.io platform. In the project, financial ratios of companies such as liquidity, profitability, indebtedness, investment performance will be calculated and changes in the financial performance of companies will be analyzed with time series analysis. In addition, sectoral comparisons will be made, crisis period analysis will be carried out and financial risks will be evaluated.
#
# This is a comprehensive dataset including numerous financial metrics that many professionals and investing gurus often use to value companies. This data is a look at the companies that comprise the S&P 500 (Standard & Poor's 500). The S&P 500 is a capitalization-weighted index of the top 500 publicly traded companies in the United States (top 500 meaning the companies with the largest market cap). The S&P 500 index is a useful index to study because it generally reflects the health of the overall U.S. stock market. The dataset was last updated in July 2020.
#
# Data Source : https://datahub.io/core/s-and-p-500-companies-financials/r/1.html

# %% [markdown]
# ## Data Set Introduction

# %% [markdown]
#   - 4 character variables:
#     - **Symbol:** Ticker symbol used to uniquely identify each company on a particular stock market
#     - **Name:** Legal name of the company
#     - **Sector:** An area of the economy where businesses share a related product or service
#     - **SEC Filings:** Helpful documents relating to a company
#
#   - 10 numeric variables:
#     - **Price:** Price per share of the company
#     - **Price to Earnings (PE):** The ratio of a company’s share price to its earnings per share
#     - **Dividend Yield:** The ratio of the annual dividends per share divided by the price per share
#     - **Earnings Per Share (EPS):** A company’s profit divided by the number of shares of its stock
#     - **52 week high and low:** The annual high and low of a company’s share price
#     - **Market Cap:** The market value of a company’s shares (calculated as share price x number of shares)
#     - **EBITDA:** A company’s earnings before interest, taxes, depreciation, and amortization; often used as a proxy for its profitability
#     - **Price to Sales (PS):** A company’s market cap divided by its total sales or revenue over the past year
#     - **Price to Book (PB):** A company’s price per share divided by its book value

# %% [markdown]
# ## Description of the Problem

# %% [markdown]
#  This project aims to understand and compare the financial position of S&P 500 companies by using different analytical methods such as evaluating the financial performance of S&P 500 companies using financial analysis skills, performing financial ratio analysis, performing time series analysis, making sectoral comparisons.  In addition, the project also addresses the important perspective of analyzing the performance of companies during periods of financial crisis and assessing their resilience to crises.
# In this context, we will try to find answers to many questions such as the following examples.
#
#  - Which companies have the highest revenues?
#  - Which companies have the lowest revenues?
#  - What is the sectoral breakdown of companies in the S&P 500 index?
#  - Which sectors are overrepresented?
#  - Which companies have the highest net profit?
#  - Which companies have the lowest net profit?
#  - What is the distribution of companies' debt levels?
#  - Which companies have the highest debt levels?
#  - How are the asset and equity levels of companies distributed?
#  - Which companies have the highest asset and equity levels?
#  - Which sectors have the highest interest rates on average?
#  - Which sectors have the lowest interest rates on average?
#  - What is the trend in revenues and profits of companies over the years?
#  - Which companies grow or decline the fastest?
#  - What are the dividend policies of companies?
#  - Which companies have the highest dividend yield?
#  - What is the relationship between changes in companies' stock prices and trading volumes?
#  - Which financial indicators affect the stock performance of companies?
#  - Which indicators have a stronger correlation?

# %% [markdown]
# ## Project Phases

# %% [markdown]
# **Data Discovery and Data Quality Assessment:** Assessing data quality by examining the dataset, identifying and organizing missing or erroneous data.
#
# **Data Visualization and Statistical Analysis:** Presenting data in an understandable and effective way with visual and statistical analysis, visually analyzing the financial performance of companies.
#
# **Financial Ratio Analysis:** Calculating and interpreting financial ratios to assess the financial health of companies, analyzing companies' financial ratios such as liquidity, profitability, indebtedness, investment performance.
#
# **Time Series Analysis:** Identify changes in the financial performance of companies by conducting time series analysis, revealing trends and patterns.
#
# **Sectoral Comparisons:** Comparing the performance of companies against sector averages, identifying sectoral trends and differences.
#
# **Crisis Period Analyses:** Analyzing the performance of companies during periods of financial crisis, assessing their resilience to crises, examining the impact of crises on the financial performance of companies.
#
# **Recommendations and Strategies:** Presenting recommendations and strategies for companies by evaluating the results obtained, identifying potential steps to improve the financial performance of companies.
#
# **Report and Presentation:** Preparing a detailed report and presentation to share the findings of the project and effectively communicate the results of the project.

# %% [markdown]
# ## Proje Pieces

# %% [markdown]
# **Literature Review:** In order to see other works in Time Series and understand what kind of new perspectives we can bring while learning the math behind it.
#
# **Data Manipulation:** Gathering data from different datasets and splitting it to do visualizations easier. For example, sectoral segregation and evaluating them seperately.
#
# **Visualization:** Exploratory Data Analysis. Before modelling we will try to understand data better so that we can chose the best models with better accuracy. We will use pie charts for the distribuiton of product sales and heatmaps to see the correlation between columns.
#
# **Modelling:** After understanding the topic better and cleaning our data we will create our model for forecasting. After that we will evaluate our model to see if we can improve it by changing the algorithm or feature engineering.
#
# **Analysis:** After all visualizations and modellings, we will cocnlude our models and graphics to answer our questions.
#
# **Reporting:** Reporting the project outputs. Prepare a report including the results of the project, analysis and interpretation.

# %% [markdown]
# ## Technologies & Metodologies

# %% [markdown]
# Tells us what kind of methods you want to apply in this project to find For prediction we are planning to use: **Linear Regression, XGBoost, Random Forest**
# For clustering we will consider:**k-means, Hierarchical clustering** answer to your research problems defined above.
#
# We will use Python programming language with its major libraries like Numpy, Pandas, Sklearn, Matplotlib, Seaborn and Scipy and Jupyter Notebook & VS Code as environment. In the reporting part, we want to use business intelligence programs such as Tableau, Power BI.
#
# We also plan to use modules like Feather and Datatable to optimize the reading and use of datasets.

# %% [markdown]
# ## Data Exploration

# %%
import pandas as pd
import requests
from io import StringIO
import time
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://datahub.io/core/s-and-p-500-companies-financials/r/1.csv'

try:
    response = requests.get(url)
    response.raise_for_status()
    data = response.text
    df = pd.read_csv(StringIO(data))
except requests.exceptions.RequestException as e:
    print(f'Internet connection error. Error: {e}')
    print('Reading from local directory...')
    time.sleep(3)
    local_file_path = 'datasets/s-and-p-500-companies-financials.csv'
    df = pd.read_csv(local_file_path)

# %%
df.head()
# Out:
#   Symbol                 Name                  Sector   Price  Price/Earnings  \
# 0    MMM           3M Company             Industrials  222.89           24.31
# 1    AOS      A.O. Smith Corp             Industrials   60.24           27.76
# 2    ABT  Abbott Laboratories             Health Care   56.27           22.51
# 3   ABBV          AbbVie Inc.             Health Care  108.48           19.41
# 4    ACN        Accenture plc  Information Technology  150.51           25.47
#
#    Dividend Yield  Earnings/Share  52 Week Low  52 Week High    Market Cap  \
# 0        2.332862            7.92       259.77       175.490  138721055226
# 1        1.147959            1.70        68.39        48.925   10783419933
# 2        1.908982            0.26        64.60        42.280  102121042306
# 3        2.499560            3.29       125.86        60.050  181386347059
# 4        1.714470            5.44       162.60       114.820   98765855553
#
#          EBITDA  Price/Sales  Price/Book  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          505 non-null    object
#  1   Name            505 non-null    object
#  2   Sector          505 non-null    object
#  3   Price           505 non-null    float64
#  4   Price/Earnings  503 non-null    float64
#  5   Dividend Yield  505 non-null    float64
#  6   Earnings/Share  505 non-null    float64
#  7   52 Week Low     505 non-null    float64
#  8   52 Week High    505 non-null    float64
#  9   Market Cap      505 non-null    int64
#  10  EBITDA          505 non-null    float64
#  11  Price/Sales     505 non-null    float64
#  12  Price/Book      497 non-null    float64
#  13  SEC Filings     505 non-null    object
# dtypes: float64(9), int64(1), object(4)
# memory usage: 55.4+ KB

# %%
df.describe()
# Out:
#              Price  Price/Earnings  Dividend Yield  Earnings/Share  \
# count   505.000000      503.000000      505.000000      505.000000
# mean    103.830634       24.808390        1.895953        3.753743
# std     134.427636       41.241081        1.537214        5.689036
# min       2.820000     -251.530000        0.000000      -28.010000
# 25%      46.250000       15.350000        0.794834        1.490000
# 50%      73.920000       19.450000        1.769255        2.890000
# 75%     116.540000       25.750000        2.781114        5.140000
# max    1806.060000      520.150000       12.661196       44.090000
#
#        52 Week Low  52 Week High    Market Cap        EBITDA  Price/Sales  \
# count   505.000000    505.000000  5.050000e+02  5.050000e+02   505.000000
# mean    122.623832     83.536616  4.923944e+10  3.590328e+09     3.941705
# std     155.362140    105.725473  9.005017e+10  6.840544e+09     3.460110
# ...

# %%
print("Missing Values:\n", df.isnull().sum())
# Out:
# Missing Values:
#  Symbol            0
# Name              0
# Sector            0
# Price             0
# Price/Earnings    2
# Dividend Yield    0
# Earnings/Share    0
# 52 Week Low       0
# 52 Week High      0
# Market Cap        0
# EBITDA            0
# Price/Sales       0
# Price/Book        8
# SEC Filings       0
# dtype: int64

# %%
# Corr. Matrix
corr_matrix = df.corr()
print("Corr. Matrix:")
print(corr_matrix)

#Plotting
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Corr. Matrix:")
plt.show()
# Out:
# C:\Users\AB\AppData\Local\Temp\ipykernel_7748\2313150601.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
# Corr. Matrix:
#                    Price  Price/Earnings  Dividend Yield  Earnings/Share  \
# Price           1.000000        0.194761       -0.244630        0.591061
# Price/Earnings  0.194761        1.000000       -0.181330        0.004570
# Dividend Yield -0.244630       -0.181330        1.000000       -0.077235
# Earnings/Share  0.591061        0.004570       -0.077235        1.000000
# 52 Week Low     0.995076        0.185356       -0.244426        0.588595
# 52 Week High    0.982787        0.144700       -0.207953        0.604894
# Market Cap      0.406474        0.131381       -0.021794        0.194063
# ...

# %%
sns.scatterplot(x="Price/Sales", y="EBITDA", data=df)
plt.xlabel("Price/Sales")
plt.ylabel("Ebitda")
plt.title("Income Distribution by Sectors")
plt.show()

# %%
sns.boxplot(x="Price", y="Sector", data=df)
plt.xlabel("Sector")
plt.ylabel("Price")
plt.title("Price Distribution by Sectors")
plt.show()

# %% [markdown]
# ## Calender
#
# * **Literature review:** 1 week
# * **Data Cleaning & Exploratory Data Analysis:** 2 weeks
# * **Modelling & Evaluation:** 2 weeks
# * **Reporting:** 1 week
# * **Final Analysis & Uploading:** 3 days
#
# **Literature review will not be done seperately, it will be synchronized with other steps.**

# %% [markdown]
# ## References
#
# Data : https://datahub.io/core/s-and-p-500-companies-financials/r/1.html
